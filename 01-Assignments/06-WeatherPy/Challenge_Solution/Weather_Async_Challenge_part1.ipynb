# %% [markdown]
# ## Challenge part 1. Get the weather description and amount of percipitation for each city.
# ---
# 1. Generate a new set of 1500 random latitudes and longitudes.
# 2. Get the nearest city.
# 3. Perform an API call with the OpenWeatherMap.
# 4. Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The maximum temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
#     - If it is raining, the amount of rainfall in inches for the last hour (1 hr). If not raining = "0" inches.
#     - If it is snowing, the amount of snow in inches for the last hour (1 hr). If not snowing = "0" inches
# 5. Add the data to a new DataFrame.
# 6. Save the new DataFrame as a CSV file.
# 7. Upload the CSV file.

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The Max temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
#     - If it is raining, the amount of rain in inches for the last hour (1 hr). If not raining = "0" inches.
#     - If it is snowing, the amount of snow in inches for the last hour (1 hr). If not snowing = "0" inches
# ----
# Hint: Use try / except blocks to get the amount of rain or snow.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0        
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | valparaiso
# Processing Record 2 of Set 1 | leningradskiy
# Processing Record 3 of Set 1 | tuatapere
# Processing Record 4 of Set 1 | nakambala
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | antalaha
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | tual
# Processing Record 15 of Set 1 | goderich
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | aguimes
# Processing Record 20 of Set 1 | lokosovo
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ornskoldsvik
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | miraflores
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | pundaguitan
# Processing Record 32 of Set 1 | ban nahin
# Processing Record 33 of Set 1 | dingle
# Processing Record 34 of Set 1 | spirit river
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | kirakira
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | camocim
# Processing Record 40 of Set 1 | takoradi
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | faya
# Processing Record 46 of Set 1 | skagen
# Processing Record 47 of Set 1 | tabas
# Processing Record 48 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 1 | saint-honore
# Processing Record 50 of Set 1 | gavrilovka vtoraya
# Processing Record 1 of Set 2 | west chester
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | gasa
# Processing Record 5 of Set 2 | ancud
# Processing Record 6 of Set 2 | narsingdi
# Processing Record 7 of Set 2 | staritsa
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | port macquarie
# Processing Record 10 of Set 2 | vardo
# Processing Record 11 of Set 2 | inuvik
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | yinchuan
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | baturaja
# Processing Record 17 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 2 | olinda
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | zambezi
# Processing Record 22 of Set 2 | redmond
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | alingsas
# Processing Record 27 of Set 2 | kallidaikurichchi
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | dakar
# Processing Record 30 of Set 2 | eyl
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | smithers
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | cayenne
# Processing Record 36 of Set 2 | honiara
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | guatire
# Processing Record 41 of Set 2 | necochea
# Processing Record 42 of Set 2 | ambilobe
# Processing Record 43 of Set 2 | minab
# Processing Record 44 of Set 2 | hervey bay
# Processing Record 45 of Set 2 | puerto cabezas
# Processing Record 46 of Set 2 | sao miguel do araguaia
# Processing Record 47 of Set 2 | santander
# Processing Record 48 of Set 2 | fredericton
# Processing Record 49 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | cururupu
# Processing Record 3 of Set 3 | sembe
# Processing Record 4 of Set 3 | nuevitas
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | oistins
# Processing Record 7 of Set 3 | vestmannaeyjar
# Processing Record 8 of Set 3 | vredendal
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | derzhavinsk
# Processing Record 16 of Set 3 | paamiut
# Processing Record 17 of Set 3 | khandyga
# Processing Record 18 of Set 3 | chengam
# Processing Record 19 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 3 | santarem
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | nador
# Processing Record 26 of Set 3 | aquiraz
# Processing Record 27 of Set 3 | bouillante
# Processing Record 28 of Set 3 | yerbogachen
# Processing Record 29 of Set 3 | baykit
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | oranjemund
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | dudinka
# Processing Record 35 of Set 3 | bahawalpur
# Processing Record 36 of Set 3 | vila franca do campo
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | leshukonskoye
# Processing Record 39 of Set 3 | andenes
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | wichita falls
# Processing Record 42 of Set 3 | quelimane
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | san policarpo
# Processing Record 45 of Set 3 | longyearbyen
# Processing Record 46 of Set 3 | nelson bay
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | lata
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | beringovskiy
# Processing Record 3 of Set 4 | hammerfest
# Processing Record 4 of Set 4 | kapaa
# Processing Record 5 of Set 4 | general pico
# Processing Record 6 of Set 4 | rawah
# Processing Record 7 of Set 4 | ust-uda
# Processing Record 8 of Set 4 | bandarbeyla
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | sinazongwe
# Processing Record 11 of Set 4 | barra do garcas
# Processing Record 12 of Set 4 | gull lake
# Processing Record 13 of Set 4 | ust-nera
# Processing Record 14 of Set 4 | stromness
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | nishihara
# Processing Record 17 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 4 | rock springs
# Processing Record 19 of Set 4 | chicama
# Processing Record 20 of Set 4 | saiha
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | storforshei
# Processing Record 24 of Set 4 | oksfjord
# Processing Record 25 of Set 4 | zemio
# Processing Record 26 of Set 4 | noumea
# Processing Record 27 of Set 4 | bonthe
# Processing Record 28 of Set 4 | maniitsoq
# Processing Record 29 of Set 4 | oum hadjer
# Processing Record 30 of Set 4 | havre-saint-pierre
# Processing Record 31 of Set 4 | peniche
# Processing Record 32 of Set 4 | nome
# Processing Record 33 of Set 4 | barrow
# Processing Record 34 of Set 4 | umm kaddadah
# Processing Record 35 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | butaritari
# Processing Record 38 of Set 4 | barcelos
# Processing Record 39 of Set 4 | alice springs
# Processing Record 40 of Set 4 | padang
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | belmonte
# Processing Record 43 of Set 4 | labuhan
# Processing Record 44 of Set 4 | salamanca
# Processing Record 45 of Set 4 | znamenskoye
# Processing Record 46 of Set 4 | smolenka
# Processing Record 47 of Set 4 | ambon
# Processing Record 48 of Set 4 | northam
# Processing Record 49 of Set 4 | boda
# Processing Record 50 of Set 4 | halifax
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | pangnirtung
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | marystown
# Processing Record 5 of Set 5 | abu dhabi
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | martapura
# Processing Record 8 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | saint-augustin
# Processing Record 11 of Set 5 | jumla
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | mandalgovi
# Processing Record 14 of Set 5 | malkapur
# Processing Record 15 of Set 5 | hilo
# Processing Record 16 of Set 5 | divnomorskoye
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | sao joao da barra
# Processing Record 19 of Set 5 | charters towers
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | port lincoln
# Processing Record 22 of Set 5 | cooma
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | inta
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | morehead
# Processing Record 29 of Set 5 | beira
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | hami
# Processing Record 33 of Set 5 | santa rosa
# Processing Record 34 of Set 5 | opuwo
# Processing Record 35 of Set 5 | avera
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | mayo
# Processing Record 38 of Set 5 | alyangula
# Processing Record 39 of Set 5 | kilimatinde
# Processing Record 40 of Set 5 | orlik
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | verkhnyaya inta
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | kavaratti
# Processing Record 48 of Set 5 | tougan
# Processing Record 49 of Set 5 | norwich
# Processing Record 50 of Set 5 | cabedelo
# Processing Record 1 of Set 6 | zunyi
# Processing Record 2 of Set 6 | derazhnya
# Processing Record 3 of Set 6 | tiarei
# Processing Record 4 of Set 6 | phultala
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | acari
# Processing Record 8 of Set 6 | baglung
# Processing Record 9 of Set 6 | lubaczow
# Processing Record 10 of Set 6 | saint peter
# Processing Record 11 of Set 6 | trelleborg
# Processing Record 12 of Set 6 | khatanga
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | cockburn town
# Processing Record 15 of Set 6 | dannenberg
# Processing Record 16 of Set 6 | sterling
# Processing Record 17 of Set 6 | kaitangata
# Processing Record 18 of Set 6 | college
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | katangli
# Processing Record 22 of Set 6 | zhetybay
# City not found. Skipping...
# Processing Record 23 of Set 6 | point pleasant
# Processing Record 24 of Set 6 | cidreira
# Processing Record 25 of Set 6 | vavoua
# Processing Record 26 of Set 6 | saldanha
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | ostrovnoy
# Processing Record 29 of Set 6 | baijiantan
# Processing Record 30 of Set 6 | atka
# City not found. Skipping...
# Processing Record 31 of Set 6 | sisimiut
# Processing Record 32 of Set 6 | puerto penasco
# Processing Record 33 of Set 6 | aljezur
# Processing Record 34 of Set 6 | poum
# Processing Record 35 of Set 6 | san cristobal
# Processing Record 36 of Set 6 | severo-kurilsk
# Processing Record 37 of Set 6 | libreville
# Processing Record 38 of Set 6 | pampas
# Processing Record 39 of Set 6 | tuktoyaktuk
# Processing Record 40 of Set 6 | waingapu
# Processing Record 41 of Set 6 | preston
# Processing Record 42 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 6 | irbeyskoye
# Processing Record 44 of Set 6 | pasni
# Processing Record 45 of Set 6 | paracuru
# Processing Record 46 of Set 6 | pangkalanbuun
# Processing Record 47 of Set 6 | masuguru
# Processing Record 48 of Set 6 | turukhansk
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | sobolevo
# Processing Record 1 of Set 7 | port-cartier
# Processing Record 2 of Set 7 | thompson
# Processing Record 3 of Set 7 | vaitape
# Processing Record 4 of Set 7 | dhidhdhoo
# Processing Record 5 of Set 7 | huilong
# Processing Record 6 of Set 7 | sayaxche
# Processing Record 7 of Set 7 | thinadhoo
# Processing Record 8 of Set 7 | henties bay
# Processing Record 9 of Set 7 | ketchikan
# Processing Record 10 of Set 7 | sao gabriel da cachoeira
# Processing Record 11 of Set 7 | nyurba
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | goundam
# Processing Record 14 of Set 7 | kandrian
# Processing Record 15 of Set 7 | narsaq
# Processing Record 16 of Set 7 | mattru
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | longyan
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | challans
# Processing Record 22 of Set 7 | brae
# Processing Record 23 of Set 7 | batagay
# Processing Record 24 of Set 7 | uspenka
# Processing Record 25 of Set 7 | stornoway
# Processing Record 26 of Set 7 | penha
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | port-gentil
# Processing Record 29 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 7 | ojinaga
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | aklavik
# Processing Record 33 of Set 7 | lugo
# Processing Record 34 of Set 7 | sur
# Processing Record 35 of Set 7 | toppenish
# Processing Record 36 of Set 7 | acapulco
# Processing Record 37 of Set 7 | penzance
# Processing Record 38 of Set 7 | lokoja
# Processing Record 39 of Set 7 | mporokoso
# Processing Record 40 of Set 7 | xining
# Processing Record 41 of Set 7 | svetlaya
# Processing Record 42 of Set 7 | boyuibe
# Processing Record 43 of Set 7 | barbalha
# Processing Record 44 of Set 7 | laguna
# Processing Record 45 of Set 7 | kibaya
# Processing Record 46 of Set 7 | urupes
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | nigde
# Processing Record 49 of Set 7 | normandin
# Processing Record 50 of Set 7 | mbandaka
# Processing Record 1 of Set 8 | port elizabeth
# Processing Record 2 of Set 8 | cortez
# Processing Record 3 of Set 8 | bouna
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | havoysund
# Processing Record 6 of Set 8 | saskylakh
# Processing Record 7 of Set 8 | vilcun
# Processing Record 8 of Set 8 | bilma
# Processing Record 9 of Set 8 | bilibino
# Processing Record 10 of Set 8 | gigmoto
# Processing Record 11 of Set 8 | acajutla
# Processing Record 12 of Set 8 | salisbury
# Processing Record 13 of Set 8 | liniere
# City not found. Skipping...
# Processing Record 14 of Set 8 | tiznit
# Processing Record 15 of Set 8 | zyryanka
# Processing Record 16 of Set 8 | kayerkan
# Processing Record 17 of Set 8 | roma
# Processing Record 18 of Set 8 | vostok
# Processing Record 19 of Set 8 | isangel
# Processing Record 20 of Set 8 | kalianget
# Processing Record 21 of Set 8 | damghan
# Processing Record 22 of Set 8 | mangrol
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | talnakh
# Processing Record 25 of Set 8 | sakakah
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | samarai
# Processing Record 28 of Set 8 | jackson
# Processing Record 29 of Set 8 | mombetsu
# Processing Record 30 of Set 8 | puerto leguizamo
# Processing Record 31 of Set 8 | rock sound
# Processing Record 32 of Set 8 | sorong
# Processing Record 33 of Set 8 | nalut
# Processing Record 34 of Set 8 | praia
# Processing Record 35 of Set 8 | kwinana
# Processing Record 36 of Set 8 | sri madhopur
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 8 | nhulunbuy
# Processing Record 39 of Set 8 | mwense
# Processing Record 40 of Set 8 | rach gia
# Processing Record 41 of Set 8 | melville
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | asfi
# Processing Record 46 of Set 8 | inhambane
# Processing Record 47 of Set 8 | colina
# Processing Record 48 of Set 8 | mujiayingzi
# Processing Record 49 of Set 8 | jishou
# Processing Record 50 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | mayskiy
# Processing Record 2 of Set 9 | atikokan
# Processing Record 3 of Set 9 | deputatskiy
# Processing Record 4 of Set 9 | tomatlan
# Processing Record 5 of Set 9 | tuensang
# Processing Record 6 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | klaksvik
# Processing Record 8 of Set 9 | ponta do sol
# Processing Record 9 of Set 9 | sahuaripa
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | uaua
# Processing Record 13 of Set 9 | newport
# Processing Record 14 of Set 9 | nadvoitsy
# Processing Record 15 of Set 9 | beitbridge
# Processing Record 16 of Set 9 | anadyr
# Processing Record 17 of Set 9 | tuy hoa
# Processing Record 18 of Set 9 | ron
# Processing Record 19 of Set 9 | usinsk
# Processing Record 20 of Set 9 | uvinza
# Processing Record 21 of Set 9 | byron bay
# Processing Record 22 of Set 9 | ogembo
# Processing Record 23 of Set 9 | ust-ordynskiy
# Processing Record 24 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 9 | stara vyzhivka
# Processing Record 26 of Set 9 | vanimo
# Processing Record 27 of Set 9 | guadix
# Processing Record 28 of Set 9 | north bend
# Processing Record 29 of Set 9 | utete
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | gravelbourg
# Processing Record 35 of Set 9 | villarrica
# Processing Record 36 of Set 9 | meadow lake
# Processing Record 37 of Set 9 | lisakovsk
# Processing Record 38 of Set 9 | ballina
# Processing Record 39 of Set 9 | revda
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | meadville
# Processing Record 42 of Set 9 | broken hill
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | pimampiro
# Processing Record 45 of Set 9 | kindu
# Processing Record 46 of Set 9 | juba
# Processing Record 47 of Set 9 | kattivakkam
# Processing Record 48 of Set 9 | quatre cocos
# Processing Record 49 of Set 9 | omboue
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 10 | tucano
# Processing Record 3 of Set 10 | kochubey
# Processing Record 4 of Set 10 | port hardy
# Processing Record 5 of Set 10 | nouadhibou
# Processing Record 6 of Set 10 | hatillo
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | novyy urgal
# Processing Record 9 of Set 10 | ndele
# Processing Record 10 of Set 10 | kloulklubed
# Processing Record 11 of Set 10 | smoky lake
# Processing Record 12 of Set 10 | taltal
# Processing Record 13 of Set 10 | honningsvag
# Processing Record 14 of Set 10 | sabha
# Processing Record 15 of Set 10 | ola
# Processing Record 16 of Set 10 | pangoa
# Processing Record 17 of Set 10 | makakilo city
# Processing Record 18 of Set 10 | chumikan
# Processing Record 19 of Set 10 | farafangana
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | tura
# Processing Record 22 of Set 10 | ken caryl
# Processing Record 23 of Set 10 | punta de piedra
# Processing Record 24 of Set 10 | marsassoum
# Processing Record 25 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 10 | tula
# Processing Record 27 of Set 10 | evensk
# Processing Record 28 of Set 10 | saint anthony
# Processing Record 29 of Set 10 | haimen
# Processing Record 30 of Set 10 | hawick
# Processing Record 31 of Set 10 | cumana
# Processing Record 32 of Set 10 | le robert
# Processing Record 33 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 10 | brainerd
# Processing Record 35 of Set 10 | gavle
# Processing Record 36 of Set 10 | koboko
# Processing Record 37 of Set 10 | cabra
# Processing Record 38 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 10 | birao
# Processing Record 40 of Set 10 | caraballeda
# Processing Record 41 of Set 10 | puri
# Processing Record 42 of Set 10 | niksic
# Processing Record 43 of Set 10 | saint-louis
# Processing Record 44 of Set 10 | cairns
# Processing Record 45 of Set 10 | bagotville
# Processing Record 46 of Set 10 | dauphin
# Processing Record 47 of Set 10 | harnosand
# Processing Record 48 of Set 10 | bastia
# Processing Record 49 of Set 10 | moose factory
# Processing Record 50 of Set 10 | vila velha
# Processing Record 1 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 2 of Set 11 | santa isabel do rio negro
# Processing Record 3 of Set 11 | berdigestyakh
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 11 | buala
# Processing Record 7 of Set 11 | sovetskiy
# Processing Record 8 of Set 11 | axim
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | hambantota
# Processing Record 11 of Set 11 | sinnamary
# Processing Record 12 of Set 11 | porbandar
# Processing Record 13 of Set 11 | dumas
# Processing Record 14 of Set 11 | paita
# Processing Record 15 of Set 11 | maromitsa
# Processing Record 16 of Set 11 | bhola
# Processing Record 17 of Set 11 | mnogovershinnyy
# Processing Record 18 of Set 11 | biscarrosse
# Processing Record 19 of Set 11 | kutum
# Processing Record 20 of Set 11 | brest
# Processing Record 21 of Set 11 | soe
# Processing Record 22 of Set 11 | meulaboh
# Processing Record 23 of Set 11 | kuminskiy
# Processing Record 24 of Set 11 | sayyan
# Processing Record 25 of Set 11 | hasaki
# Processing Record 26 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 11 | muravlenko
# Processing Record 28 of Set 11 | cangzhou
# Processing Record 29 of Set 11 | kuryk
# Processing Record 30 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | olginskaya
# Processing Record 32 of Set 11 | aberdeen
# Processing Record 33 of Set 11 | pagudpud
# Processing Record 34 of Set 11 | hobyo
# Processing Record 35 of Set 11 | camana
# Processing Record 36 of Set 11 | rudbar
# Processing Record 37 of Set 11 | shangzhi
# Processing Record 38 of Set 11 | lamar
# Processing Record 39 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 11 | rassvet
# Processing Record 41 of Set 11 | gracac
# Processing Record 42 of Set 11 | murdochville
# Processing Record 43 of Set 11 | davila
# Processing Record 44 of Set 11 | watford
# Processing Record 45 of Set 11 | kamaishi
# Processing Record 46 of Set 11 | agadez
# Processing Record 47 of Set 11 | gari
# Processing Record 48 of Set 11 | tautira
# Processing Record 49 of Set 11 | basco
# Processing Record 50 of Set 11 | kanye
# Processing Record 1 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | antofagasta
# Processing Record 3 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 12 | hongjiang
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | kang
# Processing Record 7 of Set 12 | almenevo
# City not found. Skipping...
# Processing Record 8 of Set 12 | misratah
# Processing Record 9 of Set 12 | vanderhoof
# Processing Record 10 of Set 12 | tessalit
# Processing Record 11 of Set 12 | salta
# Processing Record 12 of Set 12 | changqing
# Processing Record 13 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 12 | skibbereen
# Processing Record 15 of Set 12 | yaan
# Processing Record 16 of Set 12 | kudahuvadhoo
# Processing Record 17 of Set 12 | santa rosalia
# Processing Record 18 of Set 12 | maragogi
# Processing Record 19 of Set 12 | mount pleasant
# Processing Record 20 of Set 12 | ambanja
# Processing Record 21 of Set 12 | matagami
# Processing Record 22 of Set 12 | west lafayette
# Processing Record 23 of Set 12 | wanxian
# Processing Record 24 of Set 12 | mosquera
# Processing Record 25 of Set 12 | forbes
# Processing Record 26 of Set 12 | jalpan
# Processing Record 27 of Set 12 | chiredzi
# Processing Record 28 of Set 12 | tlacotepec
# Processing Record 29 of Set 12 | araouane
# Processing Record 30 of Set 12 | aegviidu
# Processing Record 31 of Set 12 | valleyview
# Processing Record 32 of Set 12 | poya
# Processing Record 33 of Set 12 | whitehorse
# Processing Record 34 of Set 12 | iberia
# Processing Record 35 of Set 12 | maloy
# Processing Record 36 of Set 12 | linda
# Processing Record 37 of Set 12 | pacasmayo
# Processing Record 38 of Set 12 | saint-joseph
# Processing Record 39 of Set 12 | teguldet
# Processing Record 40 of Set 12 | salekhard
# Processing Record 41 of Set 12 | trincomalee
# Processing Record 42 of Set 12 | hanna
# Processing Record 43 of Set 12 | minas novas
# Processing Record 44 of Set 12 | atar
# Processing Record 45 of Set 12 | sao raimundo nonato
# Processing Record 46 of Set 12 | lucapa
# Processing Record 47 of Set 12 | lagoa
# Processing Record 48 of Set 12 | likasi
# Processing Record 49 of Set 12 | tazovskiy
# Processing Record 50 of Set 12 | kabinda
# Processing Record 1 of Set 13 | rio grande
# Processing Record 2 of Set 13 | berezovyy
# Processing Record 3 of Set 13 | namatanai
# Processing Record 4 of Set 13 | guerrero negro
# Processing Record 5 of Set 13 | bujumbura
# Processing Record 6 of Set 13 | roebourne
# Processing Record 7 of Set 13 | mgandu
# Processing Record 8 of Set 13 | chingirlau
# Processing Record 9 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 11 of Set 13 | danielskuil
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | kongolo
# Processing Record 14 of Set 13 | pokosnoye
# Processing Record 15 of Set 13 | palu
# Processing Record 16 of Set 13 | moron
# Processing Record 17 of Set 13 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 570

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0     Valparaiso -33.04  -71.63     69.80          few clouds            0.0
# 1  Leningradskiy  69.38  178.42     24.84     overcast clouds            0.0
# 2      Tuatapere -46.13  167.68     47.46     overcast clouds            0.0
# 3      Nakambala -15.83   27.78     69.04           clear sky            0.0
# 4        Mataura -46.19  168.86     42.12     overcast clouds            0.0
# 5    Port Alfred -33.59   26.89     64.99           clear sky            0.0
# 6         Atuona  -9.80 -139.03     81.90           clear sky            0.0
# 7       Coquimbo -29.95  -71.34     60.80          few clouds            0.0
# 8       Antalaha -14.90   50.28     74.16       broken clouds            0.0
# 9         Albany  42.60  -73.97     54.00           clear sky            0.0
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0        28          21        4.70      CL
# 1            0.0        98          98        3.76      RU
# 2            0.0        82          99        4.76      NZ
# 3            0.0        31           0        3.76      ZM
# 4            0.0        86          97        3.06      NZ
# 5            0.0        76           9        7.00      ZA
# 6            0.0        67           1       15.35      PF
# 7            0.0        67          21        8.05      CL
# 8            0.0        73          69        7.02      MG
# 9            0.0        21           0       11.79      US

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description", "Rain (inches)","Snow (inches)"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Valparaiso      CL -33.04  -71.63     69.80        28          21
# 1  Leningradskiy      RU  69.38  178.42     24.84        98          98
# 2      Tuatapere      NZ -46.13  167.68     47.46        82          99
# 3      Nakambala      ZM -15.83   27.78     69.04        31           0
# 4        Mataura      NZ -46.19  168.86     42.12        86          97
# 5    Port Alfred      ZA -33.59   26.89     64.99        76           9
# 6         Atuona      PF  -9.80 -139.03     81.90        67           1
# 7       Coquimbo      CL -29.95  -71.34     60.80        67          21
# 8       Antalaha      MG -14.90   50.28     74.16        73          69
# 9         Albany      US  42.60  -73.97     54.00        21           0
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        4.70          few clouds            0.0            0.0
# 1        3.76     overcast clouds            0.0            0.0
# 2        4.76     overcast clouds            0.0            0.0
# 3        3.76           clear sky            0.0            0.0
# 4        3.06     overcast clouds            0.0            0.0
# 5        7.00           clear sky            0.0            0.0
# 6       15.35           clear sky            0.0            0.0
# 7        8.05          few clouds            0.0            0.0
# 8        7.02       broken clouds            0.0            0.0
# 9       11.79           clear sky            0.0            0.0

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Rain (inches)          float64
# Snow (inches)          float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)']>0]
raining_cities
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 26   Pundaguitan      PH   6.37  126.17     83.44        80          84
# 32      Kirakira      SB -10.45  161.92     79.00        83          85
# 34       Camocim      BR  -2.90  -40.84     85.64        74          82
# 64       Redmond      US  47.67 -122.12     55.00        80          99
# 66       Itarema      BR  -2.92  -39.92     84.24        77          89
# ..           ...     ...    ...     ...       ...       ...         ...
# 532   Tlacotepec      MX  20.07  -97.87     77.40        60          13
# 557    Namatanai      PG  -3.67  152.43     80.67        82          99
# 559    Bujumbura      BI  -3.38   29.36     74.46        73          94
# 561       Mgandu      TZ  -5.95   34.13     64.69        94          29
# 567         Palu      ID  -0.89  119.87     77.40        80          81
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 26        10.85          light rain           0.27            0.0
# 32         8.03          light rain           0.50            0.0
# 34         7.56          light rain           0.22            0.0
# 64         7.74          light rain           0.67            0.0
# 66        10.63          light rain           0.14            0.0
# ..          ...                 ...            ...            ...
# 532        5.66          light rain           0.24            0.0
# 557        7.78          light rain           0.45            0.0
# 559        3.80          light rain           0.70            0.0
# 561        3.98       moderate rain           1.62            0.0
# 567        2.91          light rain           0.16            0.0
#
# [65 rows x 11 columns]

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)']>0]
snowing_cities
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 137   Provideniya      RU  64.38 -173.30     32.86        95         100
# 140  Beringovskiy      RU  63.05  179.32     31.66        98         100
# 160   Storforshei      NO  66.40   14.52     30.99        79         100
# 257     Ostrovnoy      RU  68.05   39.51     32.27        98         100
# 300       Batagay      RU  67.63  134.63     33.82        90          84
# 331     Saskylakh      RU  71.92  114.08     28.80        98          98
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 137       14.45          light snow            0.0           0.15
# 140       16.28          light snow            0.0           0.13
# 160        4.56          light snow            0.0           0.12
# 257       33.80                snow            0.0           4.84
# 300        2.91          light snow            0.0           0.14
# 331        6.85          light snow            0.0           0.21

# %%
# Create the output File (CSV)
output_data_file = "data/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
